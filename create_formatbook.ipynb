# %%
import json

# %%
import os

# %%
alldic={}
for i in os.listdir("./formats/"):
    if i[-4:]=="json":
        print(i)
        with open("./formats/"+i) as f:
            dic=json.load(f)
            alldic[i[:-5]]=dic
# Out:
# fastgwa.json
# gwascatalog.json
# gwascatalog_hm.json
# gwaslab.json
# metal.json
# mrmega.json
# pgscatalog.json
# pgscatalog_hm.json
# plink.json
# plink2.json
# regenie.json
# saige.json
# ssf.json
# template.json

# %%
alldic
# Out:
# {'fastgwa': {'meta_data': {'format_name': 'fastgwa',
#    'format_source': 'https://yanglab.westlake.edu.cn/software/gcta/#fastGWA',
#    'format_source2': 'https://yanglab.westlake.edu.cn/software/gcta/#fastGWA-GLMM',
#    'format_version': '20220726'},
#   'format_dict': {'SNP': 'SNPID',
#    'CHR': 'CHR',
#    'POS': 'POS',
#    'A2': 'NEA',
#    'A1': 'EA',
#    'AF1': 'EAF',
#    'BETA': 'BETA',
#    'SE': 'SE',
#    'P': 'P'}},
#  'gwascatalog': {'meta_data': {'format_name': 'gwascatalog',
#    'format_source': 'https://www.ebi.ac.uk/gwas/docs/methods/summary-statistics',
#    'format_version': '20220726'},
#   'format_dict': {'variant_id': 'SNPID',
#    'chromosome': 'CHR',
#    'base_pair_location': 'POS',
#    'other_allele': 'NEA',
#    'effect_allele': 'EA',
#    'beta': 'BETA',
#    'effect_allele_frequency': 'EAF',
#    'standard_error': 'SE',
#    'p-value': 'P',
#    'odds_ratio': 'OR',
#    'ci_lower': 'OR_95L',
#    'ci_upper': 'OR_95U'}},
#  'gwascatalog_hm': {'meta_data': {'format_name': 'gwascatalog_hm',
#    'format_source': 'https://www.ebi.ac.uk/gwas/docs/methods/summary-statistics',
#    'format_version': 20220806},
#   'format_dict': {'hm_variant_id': 'SNPID',
#    'chromosome': 'CHR',
#    'base_pair_location': 'POS',
#    'hm_other_allele': 'NEA',
#    'hm_effect_allele': 'EA',
#    'hm_beta': 'BETA',
#    'hm_effect_allele_frequency': 'EAF',
#    'standard_error': 'SE',
#    'p-value': 'P',
#    'hm_odds_ratio': 'OR',
#    'hm_ci_lower': 'OR_95L',
#    'hm_ci_upper': 'OR_95U'}},
#  'gwaslab': {'meta_data': {'format_name': 'gwaslab',
#    'format_source': 'https://cloufield.github.io/gwaslab/',
#    'format_version': '20220729_v3'},
#   'format_dict': {'SNPID': 'SNPID',
#    'rsID': 'rsID',
#    'CHR': 'CHR',
#    'POS': 'POS',
#    'NEA': 'NEA',
#    'EA': 'EA',
#    'N': 'N',
#    'BETA': 'BETA',
#    'SE': 'SE',
#    'P': 'P',
#    'INFO': 'INFO',
#    'OR': 'OR',
#    'OR_95L': 'OR_95L',
#    'OR_95U': 'OR_95U',
#    'MLOG10': 'MLOG10',
#    'CHISQ': 'CHISQ',
#    'Z': 'Z',
#    'DIRECTION': 'DIRECTION',
#    'STATUS': 'STATUS'}},
#  'metal': {'meta_data': {'format_name': 'metal',
#    'format_source': 'https://genome.sph.umich.edu/wiki/METAL_Documentation',
#    'format_version': '20220726'},
#   'format_dict': {'MarkerName': 'SNPID',
#    'Allele1': 'EA',
#    'Allele2': 'NEA',
#    'Freq1': 'EAF',
#    'Effect': 'BETA',
#    'StdErr': 'SE',
#    'P-value': 'P',
#    'Direction': 'DIRECTION'}},
#  'mrmega': {'meta_data': {'format_name': 'mrmega',
#    'format_source': 'https://genomics.ut.ee/en/tools',
#    'format_version': 'ver0.2',
#    'last_check_date': 20220806},
#   'format_dict': {'MarkerName ': 'SNPID',
#    'Chromosome': 'CHR',
#    'Position': 'POS',
#    'NEA': 'NEA',
#    'EA': 'EA',
#    'EAF': 'EAF',
#    'Nsample': 'N',
#    'Effects': 'DIRECTION',
#    'chisq_association': 'CHISQ',
#    'ndf_association': 'ndf_association',
#    'P-value_association': 'P'}},
#  'pgscatalog': {'meta_data': {'format_name': 'pgscatalog',
#    'format_source': 'https://www.pgscatalog.org/downloads/',
#    'format_version': '20220726'},
#   'format_dict': {'rsID': 'rsID',
#    'chr_name': 'CHR',
#    'chr_position': 'POS',
#    'other_allele': 'NEA',
#    'effect_allele': 'EA',
#    'allelefrequency_effect': 'EAF',
#    'effect_weight': 'BETA',
#    'OR': 'OR'}},
#  'pgscatalog_hm': {'meta_data': {'format_name': 'pgscatalog_hm',
#    'format_source': 'https://www.pgscatalog.org/downloads/',
#    'format_version': '20220726'},
#   'format_dict': {'other_allele': 'NEA',
#    'effect_allele': 'EA',
#    'allelefrequency_effect': 'EAF',
#    'effect_weight': 'BETA',
#    'OR': 'OR',
#    'hm_rsID': 'rsID',
#    'hm_chr': 'CHR',
#    'hm_pos': 'POS',
#    'hm_inferOtherAllele': 'NEA'}},
#  'plink': {'meta_data': {'format_name': '.assoc.linear, .assoc.logistic, .assoc.dosage',
#    'format_source': 'https://www.cog-genomics.org/plink/1.9/',
#    'format_version': 'Stable (beta 6.26, 2 Apr)'},
#   'format_dict': {'SNP': 'rsID',
#    'CHR': 'CHR',
#    'BP': 'POS',
#    'A2': 'NEA',
#    'A1': 'EA',
#    'BETA': 'BETA',
#    'OR': 'OR',
#    'SE': 'SE',
#    'P': 'P',
#    'INFO': 'INFO',
#    'L95': 'OR_95L',
#    'H95': 'OR_95U',
#    'STAT': 'Z',
#    'NMISS': 'N'}},
#  'plink2': {'meta_data': {'format_name': 'PLINK2 .glm.firth, .glm.logistic,.glm.linear',
#    'format_source': 'https://www.cog-genomics.org/plink/2.0/formats',
#    'format_version': 'Alpha 3.3 final (3 Jun)',
#    'last_check_date': 20220806},
#   'format_dict': {'ID': 'SNPID',
#    'CHROM': 'CHR',
#    'POS': 'POS',
#    'REF': 'NEA',
#    'ALT': 'EA',
#    'OBS_CT': 'N',
#    'A1_FREQ': 'EAF',
#    'BETA': 'BETA',
#    '[LOG(OR)_]SE': 'SE',
#    'Z_[OR_F_]STAT': 'Z',
#    'P': 'P',
#    'MACH_R2': 'INFO',
#    'OR': 'OR',
#    'L95': 'OR_95L',
#    'U95': 'OR_95U'}},
#  'regenie': {'meta_data': {'format_name': 'regenie',
#    'format_source_1': 'https://rgcgithub.github.io/regenie/',
#    'format_source_2': 'https://github.com/rgcgithub/regenie/blob/master/example/test_bin_out_firth_Y1.regenie',
#    'format_version': '20220726',
#    'last_check_date': 20220806},
#   'format_dict': {'ID': 'SNPID',
#    'CHROM': 'CHR',
#    'GENPOS': 'POS',
#    'ALLELE0': 'NEA',
#    'ALLELE1': 'EA',
#    'A1FREQ': 'EAF',
#    'N': 'N',
#    'BETA': 'BETA',
#    'SE': 'SE',
#    'CHISQ': 'CHISQ',
#    'LOG10P': 'MLOG10P'}},
#  'saige': {'meta_data': {'format_name': 'saige',
#    'format_source': 'https://saigegit.github.io//SAIGE-doc/docs/single_step2.html',
#    'format_version': 'v1.1.3',
#    'last_check_date': 20220806},
#   'format_dict': {'SNPID': 'SNPID',
#    'CHR': 'CHR',
#    'POS': 'POS',
#    'Allele1': 'NEA',
#    'Allele2': 'EA',
#    'AF_Allele2': 'EAF',
#    'N': 'N',
#    'BETA': 'BETA',
#    'SE': 'SE',
#    'p.value': 'P',
#    'imputationInfo': 'INFO'}},
#  'ssf': {'meta_data': {'format_name': 'ssf',
#    'format_source': 'https://www.biorxiv.org/content/10.1101/2022.07.15.500230v1.full',
#    'format_version': 20220726},
#   'format_dict': {'variant_id': 'SNPID',
#    'rsid': 'rsID',
#    'chromosome': 'CHR',
#    'bas_pair_location': 'POS',
#    'other_allele': 'NEA',
#    'effect_allele': 'EA',
#    'n': 'N',
#    'beta': 'BETA',
#    'standard_error': 'SE',
#    'p_value': 'P',
#    'info': 'INFO',
#    'odds_ratio': 'OR',
#    'ci_lower': 'OR_95L',
#    'ci_upper': 'OR_95U'}},
#  'template': {'meta_data': {'format_name': '',
#    'format_source': '',
#    'format_version': '20220726'},
#   'format_dict': {'': 'OR_95U'}}}

# %%
with open('./formatbook.json', 'w') as f:
    json.dump(alldic,f,indent=4)

# %%
book=json.load(open("formatbook.json"))

# %%
book
# Out:
# {'fastgwa': {'meta_data': {'format_name': 'fastgwa',
#    'format_source': 'https://yanglab.westlake.edu.cn/software/gcta/#fastGWA',
#    'format_source2': 'https://yanglab.westlake.edu.cn/software/gcta/#fastGWA-GLMM',
#    'format_version': '20220726'},
#   'format_dict': {'SNP': 'SNPID',
#    'CHR': 'CHR',
#    'POS': 'POS',
#    'A2': 'NEA',
#    'A1': 'EA',
#    'AF1': 'EAF',
#    'BETA': 'BETA',
#    'SE': 'SE',
#    'P': 'P'}},
#  'gwascatalog': {'meta_data': {'format_name': 'gwascatalog',
#    'format_source': 'https://www.ebi.ac.uk/gwas/docs/methods/summary-statistics',
#    'format_version': '20220726'},
#   'format_dict': {'variant_id': 'SNPID',
#    'chromosome': 'CHR',
#    'base_pair_location': 'POS',
#    'other_allele': 'NEA',
#    'effect_allele': 'EA',
#    'beta': 'BETA',
#    'effect_allele_frequency': 'EAF',
#    'standard_error': 'SE',
#    'p-value': 'P',
#    'odds_ratio': 'OR',
#    'ci_lower': 'OR_95L',
#    'ci_upper': 'OR_95U'}},
#  'gwascatalog_hm': {'meta_data': {'format_name': 'gwascatalog_hm',
#    'format_source': 'https://www.ebi.ac.uk/gwas/docs/methods/summary-statistics',
#    'format_version': 20220806},
#   'format_dict': {'hm_variant_id': 'SNPID',
#    'chromosome': 'CHR',
#    'base_pair_location': 'POS',
#    'hm_other_allele': 'NEA',
#    'hm_effect_allele': 'EA',
#    'hm_beta': 'BETA',
#    'hm_effect_allele_frequency': 'EAF',
#    'standard_error': 'SE',
#    'p-value': 'P',
#    'hm_odds_ratio': 'OR',
#    'hm_ci_lower': 'OR_95L',
#    'hm_ci_upper': 'OR_95U'}},
#  'gwaslab': {'meta_data': {'format_name': 'gwaslab',
#    'format_source': 'https://cloufield.github.io/gwaslab/',
#    'format_version': '20220729_v3'},
#   'format_dict': {'SNPID': 'SNPID',
#    'rsID': 'rsID',
#    'CHR': 'CHR',
#    'POS': 'POS',
#    'NEA': 'NEA',
#    'EA': 'EA',
#    'N': 'N',
#    'BETA': 'BETA',
#    'SE': 'SE',
#    'P': 'P',
#    'INFO': 'INFO',
#    'OR': 'OR',
#    'OR_95L': 'OR_95L',
#    'OR_95U': 'OR_95U',
#    'MLOG10': 'MLOG10',
#    'CHISQ': 'CHISQ',
#    'Z': 'Z',
#    'DIRECTION': 'DIRECTION',
#    'STATUS': 'STATUS'}},
#  'metal': {'meta_data': {'format_name': 'metal',
#    'format_source': 'https://genome.sph.umich.edu/wiki/METAL_Documentation',
#    'format_version': '20220726'},
#   'format_dict': {'MarkerName': 'SNPID',
#    'Allele1': 'EA',
#    'Allele2': 'NEA',
#    'Freq1': 'EAF',
#    'Effect': 'BETA',
#    'StdErr': 'SE',
#    'P-value': 'P',
#    'Direction': 'DIRECTION'}},
#  'mrmega': {'meta_data': {'format_name': 'mrmega',
#    'format_source': 'https://genomics.ut.ee/en/tools',
#    'format_version': 'ver0.2',
#    'last_check_date': 20220806},
#   'format_dict': {'MarkerName ': 'SNPID',
#    'Chromosome': 'CHR',
#    'Position': 'POS',
#    'NEA': 'NEA',
#    'EA': 'EA',
#    'EAF': 'EAF',
#    'Nsample': 'N',
#    'Effects': 'DIRECTION',
#    'chisq_association': 'CHISQ',
#    'ndf_association': 'ndf_association',
#    'P-value_association': 'P'}},
#  'pgscatalog': {'meta_data': {'format_name': 'pgscatalog',
#    'format_source': 'https://www.pgscatalog.org/downloads/',
#    'format_version': '20220726'},
#   'format_dict': {'rsID': 'rsID',
#    'chr_name': 'CHR',
#    'chr_position': 'POS',
#    'other_allele': 'NEA',
#    'effect_allele': 'EA',
#    'allelefrequency_effect': 'EAF',
#    'effect_weight': 'BETA',
#    'OR': 'OR'}},
#  'pgscatalog_hm': {'meta_data': {'format_name': 'pgscatalog_hm',
#    'format_source': 'https://www.pgscatalog.org/downloads/',
#    'format_version': '20220726'},
#   'format_dict': {'other_allele': 'NEA',
#    'effect_allele': 'EA',
#    'allelefrequency_effect': 'EAF',
#    'effect_weight': 'BETA',
#    'OR': 'OR',
#    'hm_rsID': 'rsID',
#    'hm_chr': 'CHR',
#    'hm_pos': 'POS',
#    'hm_inferOtherAllele': 'NEA'}},
#  'plink': {'meta_data': {'format_name': '.assoc.linear, .assoc.logistic, .assoc.dosage',
#    'format_source': 'https://www.cog-genomics.org/plink/1.9/',
#    'format_version': 'Stable (beta 6.26, 2 Apr)'},
#   'format_dict': {'SNP': 'rsID',
#    'CHR': 'CHR',
#    'BP': 'POS',
#    'A2': 'NEA',
#    'A1': 'EA',
#    'BETA': 'BETA',
#    'OR': 'OR',
#    'SE': 'SE',
#    'P': 'P',
#    'INFO': 'INFO',
#    'L95': 'OR_95L',
#    'H95': 'OR_95U',
#    'STAT': 'Z',
#    'NMISS': 'N'}},
#  'plink2': {'meta_data': {'format_name': 'PLINK2 .glm.firth, .glm.logistic,.glm.linear',
#    'format_source': 'https://www.cog-genomics.org/plink/2.0/formats',
#    'format_version': 'Alpha 3.3 final (3 Jun)',
#    'last_check_date': 20220806},
#   'format_dict': {'ID': 'SNPID',
#    'CHROM': 'CHR',
#    'POS': 'POS',
#    'REF': 'NEA',
#    'ALT': 'EA',
#    'OBS_CT': 'N',
#    'A1_FREQ': 'EAF',
#    'BETA': 'BETA',
#    '[LOG(OR)_]SE': 'SE',
#    'Z_[OR_F_]STAT': 'Z',
#    'P': 'P',
#    'MACH_R2': 'INFO',
#    'OR': 'OR',
#    'L95': 'OR_95L',
#    'U95': 'OR_95U'}},
#  'regenie': {'meta_data': {'format_name': 'regenie',
#    'format_source_1': 'https://rgcgithub.github.io/regenie/',
#    'format_source_2': 'https://github.com/rgcgithub/regenie/blob/master/example/test_bin_out_firth_Y1.regenie',
#    'format_version': '20220726',
#    'last_check_date': 20220806},
#   'format_dict': {'ID': 'SNPID',
#    'CHROM': 'CHR',
#    'GENPOS': 'POS',
#    'ALLELE0': 'NEA',
#    'ALLELE1': 'EA',
#    'A1FREQ': 'EAF',
#    'N': 'N',
#    'BETA': 'BETA',
#    'SE': 'SE',
#    'CHISQ': 'CHISQ',
#    'LOG10P': 'MLOG10P'}},
#  'saige': {'meta_data': {'format_name': 'saige',
#    'format_source': 'https://saigegit.github.io//SAIGE-doc/docs/single_step2.html',
#    'format_version': 'v1.1.3',
#    'last_check_date': 20220806},
#   'format_dict': {'SNPID': 'SNPID',
#    'CHR': 'CHR',
#    'POS': 'POS',
#    'Allele1': 'NEA',
#    'Allele2': 'EA',
#    'AF_Allele2': 'EAF',
#    'N': 'N',
#    'BETA': 'BETA',
#    'SE': 'SE',
#    'p.value': 'P',
#    'imputationInfo': 'INFO'}},
#  'ssf': {'meta_data': {'format_name': 'ssf',
#    'format_source': 'https://www.biorxiv.org/content/10.1101/2022.07.15.500230v1.full',
#    'format_version': 20220726},
#   'format_dict': {'variant_id': 'SNPID',
#    'rsid': 'rsID',
#    'chromosome': 'CHR',
#    'bas_pair_location': 'POS',
#    'other_allele': 'NEA',
#    'effect_allele': 'EA',
#    'n': 'N',
#    'beta': 'BETA',
#    'standard_error': 'SE',
#    'p_value': 'P',
#    'info': 'INFO',
#    'odds_ratio': 'OR',
#    'ci_lower': 'OR_95L',
#    'ci_upper': 'OR_95U'}},
#  'template': {'meta_data': {'format_name': '',
#    'format_source': '',
#    'format_version': '20220726'},
#   'format_dict': {'': 'OR_95U'}}}
